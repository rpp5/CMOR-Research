# %% [markdown]
# Generate 1000 Knapsack instances, and create node dfs for each instance

# %%
import numpy as np
import pandas as pd
from knapsack_functions import *

# %%
df_complete = build_training_set(num_instances=1000, num_items = 5)
# Out:
# 119.0 IS THE OPTIMAL VALUE
# 139.0 IS THE OPTIMAL VALUE
# 80.0 IS THE OPTIMAL VALUE
# 69.0 IS THE OPTIMAL VALUE
# 102.0 IS THE OPTIMAL VALUE
# 97.0 IS THE OPTIMAL VALUE
# 108.0 IS THE OPTIMAL VALUE
# 74.0 IS THE OPTIMAL VALUE
# 107.0 IS THE OPTIMAL VALUE
# 139.0 IS THE OPTIMAL VALUE
# 95.0 IS THE OPTIMAL VALUE
# 116.0 IS THE OPTIMAL VALUE
# 97.0 IS THE OPTIMAL VALUE
# 139.0 IS THE OPTIMAL VALUE
# 103.0 IS THE OPTIMAL VALUE
# 109.0 IS THE OPTIMAL VALUE
# 120.0 IS THE OPTIMAL VALUE
# 108.0 IS THE OPTIMAL VALUE
# 127.0 IS THE OPTIMAL VALUE
# 89.0 IS THE OPTIMAL VALUE
# 93.0 IS THE OPTIMAL VALUE
# 87.0 IS THE OPTIMAL VALUE
# 67.0 IS THE OPTIMAL VALUE
# 68.0 IS THE OPTIMAL VALUE
# 89.0 IS THE OPTIMAL VALUE
# 79.0 IS THE OPTIMAL VALUE
# 103.0 IS THE OPTIMAL VALUE
# 90.0 IS THE OPTIMAL VALUE
# 134.0 IS THE OPTIMAL VALUE
# 97.0 IS THE OPTIMAL VALUE
# 103.0 IS THE OPTIMAL VALUE
# 96.0 IS THE OPTIMAL VALUE
# 115.0 IS THE OPTIMAL VALUE
# 131.0 IS THE OPTIMAL VALUE
# 120.0 IS THE OPTIMAL VALUE
# ...

# %%
df_complete
# Out:
#        node_id  parent_id  depth      status  lp_objective  objective  \
# 0            0        NaN      0  fractional    119.117647        NaN
# 1            2        0.0      1     integer    119.000000      119.0
# 2            1        0.0      1  fractional     74.400000        NaN
# 3            4        1.0      2  fractional     55.500000        NaN
# 4            6        4.0      3  fractional     44.000000        NaN
# ...        ...        ...    ...         ...           ...        ...
# 15497        9        1.0      2  fractional    123.000000        NaN
# 15498       14        9.0      3  fractional    120.111111        NaN
# 15499       16       14.0      4     integer    115.000000      115.0
# 15500       15       14.0      4  infeasible           NaN        NaN
# 15501       13        9.0      3     integer    108.000000      108.0
#
#        visit_idx  open_nodes_count  branch_parent_var  branch_parent_dir  ...  \
# ...

# %%
df_complete.columns
# Out:
# Index(['node_id', 'parent_id', 'depth', 'status', 'lp_objective', 'objective',
#        'visit_idx', 'open_nodes_count', 'branch_parent_var',
#        'branch_parent_dir', 'branch_parent_weight', 'branch_parent_value',
#        'branch_parent_ratio', 'slack', 'num_fixed', 'num_fixed_1',
#        'num_fixed_0', 'fix_ratio', 'total_weight_fixed_1',
#        'total_value_fixed_1', 'incumbent_val', 'has_incumbent', 'node_gap',
#        'node_rel_gap', 'frac_var_index', 'frac_var_normalized',
#        'frac_var_weight', 'frac_var_value', 'frac_var_ratio',
#        'frac_var_fraction', 'x0', 'x1', 'x2', 'x3', 'x4',
#        'has_optimal_subtree', 'instance_id', 'best_val', 'num_items', 'seed'],
#       dtype='object')
