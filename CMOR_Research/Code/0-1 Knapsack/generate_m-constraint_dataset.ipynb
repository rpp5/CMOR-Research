# %%
import numpy as np
import pandas as pd
from main_knapsack_functions import *

# %%
df_m = build_training_set(10, 5, generate_knapsack_mconstraint, m = 2)

# %%
df_m.head(10)
# Out:
#    node_id  parent_id  depth  visit_idx  open_nodes_count  branch_parent_var  \
# 0        0        NaN      0          0                 0                NaN
# 1        2        0.0      1          1                 1                4.0
# 2        1        0.0      1          2                 0                4.0
# 3        0        NaN      0          0                 0                NaN
# 4        2        0.0      1          1                 1                3.0
# 5        4        2.0      2          2                 2                0.0
# 6        3        2.0      2          3                 1                0.0
# 7        6        3.0      3          4                 2                1.0
# 8        5        3.0      3          5                 1                1.0
# 9        8        5.0      4          6                 2                2.0
#
#   branch_parent_dir  branch_parent_value  lp_objective  num_frac  ...  \
# ...
