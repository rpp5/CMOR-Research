# %% [markdown]
# Generate 1000 Knapsack instances, and create node dfs for each instance

# %%
import numpy as np
import pandas as pd
from knapsack_functions import *

# %%
df = build_training_instance(0)
# Out:
# 78.0 IS THE OPTIMAL VALUE

# %%
df.head()
# Out:
#    node_id  parent_id  depth      status  lp_objective  objective  visit_idx  \
# 0        0        NaN      0  fractional    106.526316        NaN          0
# 1        2        0.0      1     integer     78.000000       78.0          1
# 2        1        0.0      1  fractional     90.000000        NaN          2
# 3        4        1.0      2  fractional     82.000000        NaN          3
# 4        6        4.0      3  fractional     75.111111        NaN          4
#
#    open_nodes_count  branch_parent_var  branch_parent_dir  ...  x0   x1   x2  \
# 0                 0                NaN                NaN  ... NaN  NaN  NaN
# 1                 1                1.0                0.0  ... NaN  0.0  NaN
# 2                 0                1.0                1.0  ... NaN  1.0  NaN
# 3                 1                4.0                0.0  ... NaN  1.0  NaN
# 4                 2                2.0                0.0  ... NaN  1.0  0.0
#
#    x3   x4  has_optimal_subtree  instance_id  best_val  num_items    seed
# 0 NaN  NaN                    1            0      78.0          5  121281
# 1 NaN  NaN                    1            0      78.0          5  121281
# 2 NaN  NaN                    0            0      78.0          5  121281
# 3 NaN  0.0                    0            0      78.0          5  121281
# 4 NaN  0.0                    0            0      78.0          5  121281
#
# [5 rows x 40 columns]
